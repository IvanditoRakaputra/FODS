# %% [markdown]
# # Your task
# - Inspect a dataframe with df.head(), df.tail(), df.info(), df.describe().
# Show how many missing values in your data, each column.
#
# - Manipulate how a dataframe displays in Jupyter by modifying Pandas configuration options such as pd.set_option("display.max_rows", n).
#
# - Rename columns of a dataframe using the df.rename() function or by accessing the df.columns attribute.
#
# - Modify the index name and index values of a dataframe using .set_index(), .reset_index() , df.index.name, .index.
#
# - Use df.melt() and df.pivot() to reshape dataframes, specifically to make tidy dataframes.
#
# - Combine dataframes using df.merge() and pd.concat() and know when to use these different methods.
#
# - Apply functions to a dataframe df.apply() and df.applymap()
#
# - Find the data which satisfy specific condition using df.query()
#
# - Perform grouping and aggregating operations using df.groupby() and df.agg().
#
# - Perform aggregating methods on grouped or ungrouped objects such as finding the minimum, maximum and sum of values in a dataframe using df.agg().
#
# - Remove or fill missing values in a dataframe with df.dropna() and df.fillna() please practice using different method of filling missing value.
#
# - Practice imputing missing values using the SimpleImputer Class in sklearn

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Inspect a dataframe with df.head(), df.tail(), df.info(), df.describe().

# %%
df = pd.read_csv('pakwheels_used_car_data_v02.csv')
df2 = pd.read_csv('pakwheels_used_cars.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77878 entries, 0 to 77877
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   addref        77878 non-null  int64
#  1   city          77878 non-null  object
#  2   assembly      24189 non-null  object
#  3   body          68974 non-null  object
#  4   make          77878 non-null  object
#  5   model         77878 non-null  object
#  6   year          73099 non-null  float64
#  7   engine        77875 non-null  float64
#  8   transmission  77878 non-null  object
#  9   fuel          76972 non-null  object
#  10  color         76398 non-null  object
#  11  registered    77878 non-null  object
#  12  mileage       77878 non-null  int64
#  13  price         77295 non-null  float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 8.3+ MB

# %%
df.head()
# Out:
#     addref      city assembly       body    make    model    year  engine  \
# 0  7943732  Peshawar      NaN      Sedan  Toyota  Corolla  2013.0  1300.0
# 1  7730314    Lahore      NaN      Sedan   Honda     City  2000.0  1300.0
# 2  7943737    Lahore      NaN      Sedan  Toyota    Yaris  2021.0  1300.0
# 3  7943733    Lahore      NaN  Hatchback  Suzuki    Swift  2017.0  1300.0
# 4  7923484    Lahore      NaN      Sedan   Honda    Civic  2017.0  1800.0
#
#   transmission    fuel            color registered  mileage      price
# 0       Manual  Petrol  Silver Metallic     Lahore   145000  2870000.0
# 1       Manual  Petrol             Blue     Lahore   230000   995000.0
# 2       Manual  Petrol      Super White     Punjab    60500  3585000.0
# 3       Manual  Petrol             Grey  Islamabad    87000  2250000.0
# 4    Automatic  Petrol             Grey     Lahore    86000  4850000.0

# %%
df.tail()
# Out:
#         addref        city  assembly       body    make    model    year  \
# 77873  7775164       Daska       NaN      Sedan   Honda    Civic  2019.0
# 77874  7772775  Abbottabad  Imported  Hatchback  Suzuki     Alto  2015.0
# 77875  7773716  Faisalabad  Imported  Crossover      MG       HS  2021.0
# 77876  7322377      Quetta       NaN      Sedan  Suzuki   Baleno  2005.0
# 77877  7770898       Mandi  Imported      Sedan  Toyota  Corolla  1998.0
#
#        engine transmission    fuel          color     registered  mileage  \
# 77873  1800.0    Automatic  Petrol  Taffeta White      Islamabad    58000
# 77874   660.0    Automatic  Petrol          Brown      Islamabad    65000
# 77875  1490.0    Automatic  Petrol   Arctic White  Un-Registered     5000
# 77876  1300.0       Manual  Petrol         Silver         Lahore    19000
# 77877  1600.0    Automatic  Petrol          Black         Lahore    12345
#
#            price
# 77873  5590000.0
# 77874  2420000.0
# 77875  7500000.0
# ...

# %%
df.describe()
# Out:
#              addref          year        engine         mileage         price
# count  7.787800e+04  73099.000000  77875.000000    77878.000000  7.729500e+04
# mean   7.809878e+06   2012.812610   1408.072550    91109.192750  3.883232e+06
# std    2.599523e+05      7.516685    704.459947    89275.336173  5.759480e+06
# min    2.748970e+05   1990.000000      3.000000        1.000000  1.100000e+05
# 25%    7.805760e+06   2007.000000   1000.000000    34000.000000  1.450000e+06
# 50%    7.865805e+06   2015.000000   1300.000000    80000.000000  2.700000e+06
# 75%    7.910334e+06   2019.000000   1600.000000   123456.000000  4.500000e+06
# max    7.943741e+06   2022.000000  15000.000000  1000000.000000  5.290000e+08

# %% [markdown]
# # Show how many missing values in your data, each column.

# %%
df.isnull().sum()
# Out:
# addref              0
# city                0
# assembly        53689
# body             8904
# make                0
# model               0
# year             4779
# engine              3
# transmission        0
# fuel              906
# color            1480
# registered          0
# mileage             0
# price             583
# dtype: int64

# %% [markdown]
# # Remove or fill missing values in a dataframe with df.dropna() and df.fillna() please practice using different method of filling missing value.

# %%
df.drop(['assembly','year','body','fuel','color','price'], axis=1, inplace=True)
df
# Out:
#         addref        city    make    model  engine transmission  \
# 0      7943732    Peshawar  Toyota  Corolla  1300.0       Manual
# 1      7730314      Lahore   Honda     City  1300.0       Manual
# 2      7943737      Lahore  Toyota    Yaris  1300.0       Manual
# 3      7943733      Lahore  Suzuki    Swift  1300.0       Manual
# 4      7923484      Lahore   Honda    Civic  1800.0    Automatic
# ...        ...         ...     ...      ...     ...          ...
# 77873  7775164       Daska   Honda    Civic  1800.0    Automatic
# 77874  7772775  Abbottabad  Suzuki     Alto   660.0    Automatic
# 77875  7773716  Faisalabad      MG       HS  1490.0    Automatic
# 77876  7322377      Quetta  Suzuki   Baleno  1300.0       Manual
# 77877  7770898       Mandi  Toyota  Corolla  1600.0    Automatic
#
#           registered  mileage
# 0             Lahore   145000
# 1             Lahore   230000
# 2             Punjab    60500
# 3          Islamabad    87000
# ...

# %%
df.isnull().sum()
# Out:
# addref          0
# city            0
# make            0
# model           0
# engine          3
# transmission    0
# registered      0
# mileage         0
# dtype: int64

# %%
df['engine'].fillna(df['engine'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# addref          0
# city            0
# make            0
# model           0
# engine          0
# transmission    0
# registered      0
# mileage         0
# dtype: int64

# %% [markdown]
# # Manipulate how a dataframe displays in Jupyter by modifying Pandas configuration options such as pd.set_option("display.max_rows", n).

# %%
pd.set_option("display.max_rows", 8)
pd.set_option("display.max_columns", 4)
df
# Out:
#         addref        city  ...     registered mileage
# 0      7943732    Peshawar  ...         Lahore  145000
# 1      7730314      Lahore  ...         Lahore  230000
# 2      7943737      Lahore  ...         Punjab   60500
# 3      7943733      Lahore  ...      Islamabad   87000
# ...        ...         ...  ...            ...     ...
# 77874  7772775  Abbottabad  ...      Islamabad   65000
# 77875  7773716  Faisalabad  ...  Un-Registered    5000
# 77876  7322377      Quetta  ...         Lahore   19000
# 77877  7770898       Mandi  ...         Lahore   12345
#
# [77878 rows x 8 columns]

# %%
pd.reset_option("display.max_rows")
pd.reset_option("display.max_columns")
df
# Out:
#         addref        city    make    model  engine transmission  \
# 0      7943732    Peshawar  Toyota  Corolla  1300.0       Manual
# 1      7730314      Lahore   Honda     City  1300.0       Manual
# 2      7943737      Lahore  Toyota    Yaris  1300.0       Manual
# 3      7943733      Lahore  Suzuki    Swift  1300.0       Manual
# 4      7923484      Lahore   Honda    Civic  1800.0    Automatic
# ...        ...         ...     ...      ...     ...          ...
# 77873  7775164       Daska   Honda    Civic  1800.0    Automatic
# 77874  7772775  Abbottabad  Suzuki     Alto   660.0    Automatic
# 77875  7773716  Faisalabad      MG       HS  1490.0    Automatic
# 77876  7322377      Quetta  Suzuki   Baleno  1300.0       Manual
# 77877  7770898       Mandi  Toyota  Corolla  1600.0    Automatic
#
#           registered  mileage
# 0             Lahore   145000
# 1             Lahore   230000
# 2             Punjab    60500
# 3          Islamabad    87000
# ...

# %% [markdown]
# # Rename columns of a dataframe using the df.rename() function or by accessing the df.columns attribute.

# %%
df.rename(columns={ 'addref': 'Address', 'make': 'Product', 'mileage':'Fuel Efficiency' }, inplace=True)
df.head()
# Out:
#    Address      city Product    model  engine transmission registered  \
# 0  7943732  Peshawar  Toyota  Corolla  1300.0       Manual     Lahore
# 1  7730314    Lahore   Honda     City  1300.0       Manual     Lahore
# 2  7943737    Lahore  Toyota    Yaris  1300.0       Manual     Punjab
# 3  7943733    Lahore  Suzuki    Swift  1300.0       Manual  Islamabad
# 4  7923484    Lahore   Honda    Civic  1800.0    Automatic     Lahore
#
#    Fuel Efficiency
# 0           145000
# 1           230000
# 2            60500
# 3            87000
# 4            86000

# %%
df_merge=df.merge(df2, left_on='Address', right_on='ad_ref')
df_merge
# Out:
#        Address        city   Product  model_x  engine transmission_x  \
# 0      7764683   Islamabad    Suzuki    Swift  1300.0         Manual
# 1      7894559      Lahore  Daihatsu     Move   660.0      Automatic
# 2      7907725      Lahore  Daihatsu     Move   660.0      Automatic
# 3      7894570      Lahore  Daihatsu     Move   660.0      Automatic
# 4      7855320      Lahore  Daihatsu     Move   660.0      Automatic
# ...        ...         ...       ...      ...     ...            ...
# 67259  7775164       Daska     Honda    Civic  1800.0      Automatic
# 67260  7772775  Abbottabad    Suzuki     Alto   660.0      Automatic
# 67261  7773716  Faisalabad        MG       HS  1490.0      Automatic
# 67262  7322377      Quetta    Suzuki   Baleno  1300.0         Manual
# 67263  7770898       Mandi    Toyota  Corolla  1600.0      Automatic
#
#         registered_x  Fuel Efficiency   ad_ref  assembly  ...  \
# 0          Islamabad            45000  7764683       NaN  ...
# ...

# %%
pd.concat([df,df2])
# Out:
#          Address      city Product    model  engine transmission  \
# 0      7943732.0  Peshawar  Toyota  Corolla  1300.0       Manual
# 1      7730314.0    Lahore   Honda     City  1300.0       Manual
# 2      7943737.0    Lahore  Toyota    Yaris  1300.0       Manual
# 3      7943733.0    Lahore  Suzuki    Swift  1300.0       Manual
# 4      7923484.0    Lahore   Honda    Civic  1800.0    Automatic
# ...          ...       ...     ...      ...     ...          ...
# 77232        NaN       NaN     NaN    Every     NaN       Manual
# 77233        NaN       NaN     NaN    Yaris     NaN    Automatic
# 77234        NaN       NaN     NaN    Every     NaN    Automatic
# 77235        NaN       NaN     NaN  Corolla     NaN    Automatic
# 77236        NaN       NaN     NaN    Civic     NaN    Automatic
#
#           registered  Fuel Efficiency     ad_ref  assembly       body  \
# 0             Lahore         145000.0        NaN       NaN        NaN
# ...

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67264 entries, 0 to 67263
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Address          67264 non-null  int64
#  1   city             67264 non-null  object
#  2   Product          67264 non-null  object
#  3   model_x          67264 non-null  object
#  4   engine           67264 non-null  float64
#  5   transmission_x   67264 non-null  object
#  6   registered_x     67264 non-null  object
#  7   Fuel Efficiency  67264 non-null  int64
#  8   ad_ref           67264 non-null  int64
#  9   assembly         20933 non-null  object
#  10  body             59435 non-null  object
#  11  ad_city          67264 non-null  object
#  12  color            65975 non-null  object
#  13  engine_cc        67262 non-null  float64
#  14  fuel_type        66458 non-null  object
#  15  make             67264 non-null  object
# ...

# %% [markdown]
# # Use df.melt() and df.pivot() to reshape dataframes, specifically to make tidy dataframes.

# %%
df.melt()
# Out:
#                variable    value
# 0               Address  7943732
# 1               Address  7730314
# 2               Address  7943737
# 3               Address  7943733
# 4               Address  7923484
# ...                 ...      ...
# 623019  Fuel Efficiency    58000
# 623020  Fuel Efficiency    65000
# 623021  Fuel Efficiency     5000
# 623022  Fuel Efficiency    19000
# 623023  Fuel Efficiency    12345
#
# [623024 rows x 2 columns]

# %%
df.pivot(index='Address',columns='city',values='engine')
# Out:
# city     Abbottabad  Abdul  Adda  Ahmed  Akora  Ali  Alipur  Allahabad  \
# Address
# 274897          NaN    NaN   NaN    NaN    NaN  NaN     NaN        NaN
# 447811          NaN    NaN   NaN    NaN    NaN  NaN     NaN        NaN
# 751852          NaN    NaN   NaN    NaN    NaN  NaN     NaN        NaN
# 1117870         NaN    NaN   NaN    NaN    NaN  NaN     NaN        NaN
# 1149814         NaN    NaN   NaN    NaN    NaN  NaN     NaN        NaN
# ...             ...    ...   ...    ...    ...  ...     ...        ...
# 7943736         NaN    NaN   NaN    NaN    NaN  NaN     NaN        NaN
# 7943737         NaN    NaN   NaN    NaN    NaN  NaN     NaN        NaN
# 7943739         NaN    NaN   NaN    NaN    NaN  NaN     NaN        NaN
# 7943740         NaN    NaN   NaN    NaN    NaN  NaN     NaN        NaN
# 7943741         NaN    NaN   NaN    NaN    NaN  NaN     NaN        NaN
#
# city     Amangarh  Arifwala  ...  Ubauro  Ugoke  Umer  Vehari  Wah  Wahn  \
# ...

# %% [markdown]
# # Modify the index name and index values of a dataframe using .set_index(), .reset_index() , df.index.name, .index.

# %%
df_merge.set_index('model_x',inplace = True)
df_merge.index.name = 'Type Of Cars'
df_merge.reset_index()

df_merge
# Out:
#               Address        city   Product  engine transmission_x  \
# Type Of Cars
# Swift         7764683   Islamabad    Suzuki  1300.0         Manual
# Move          7894559      Lahore  Daihatsu   660.0      Automatic
# Move          7907725      Lahore  Daihatsu   660.0      Automatic
# Move          7894570      Lahore  Daihatsu   660.0      Automatic
# Move          7855320      Lahore  Daihatsu   660.0      Automatic
# ...               ...         ...       ...     ...            ...
# Civic         7775164       Daska     Honda  1800.0      Automatic
# Alto          7772775  Abbottabad    Suzuki   660.0      Automatic
# HS            7773716  Faisalabad        MG  1490.0      Automatic
# Baleno        7322377      Quetta    Suzuki  1300.0         Manual
# Corolla       7770898       Mandi    Toyota  1600.0      Automatic
#
#                registered_x  Fuel Efficiency   ad_ref  assembly       body  \
# Type Of Cars
# ...

# %% [markdown]
# # Apply functions to a dataframe df.apply() and df.applymap()

# %%
def convert_to_uppercase(value):
    if isinstance(value, str):
        return value.upper()
    else:
        return value
    
df_merge['transmission_x'] = df_merge['transmission_x'].apply(convert_to_uppercase)
    
df_merge
# Out:
#               Address        city   Product  engine transmission_x  \
# Type Of Cars
# Swift         7764683   Islamabad    Suzuki  1300.0         MANUAL
# Move          7894559      Lahore  Daihatsu   660.0      AUTOMATIC
# Move          7907725      Lahore  Daihatsu   660.0      AUTOMATIC
# Move          7894570      Lahore  Daihatsu   660.0      AUTOMATIC
# Move          7855320      Lahore  Daihatsu   660.0      AUTOMATIC
# ...               ...         ...       ...     ...            ...
# Civic         7775164       Daska     Honda  1800.0      AUTOMATIC
# Alto          7772775  Abbottabad    Suzuki   660.0      AUTOMATIC
# HS            7773716  Faisalabad        MG  1490.0      AUTOMATIC
# Baleno        7322377      Quetta    Suzuki  1300.0         MANUAL
# Corolla       7770898       Mandi    Toyota  1600.0      AUTOMATIC
#
#                registered_x  Fuel Efficiency   ad_ref  assembly       body  \
# Type Of Cars
# ...

# %%
df.applymap(lambda x: len(str(x)))
# Out:
#        Address  city  Product  model  engine  transmission  registered  \
# 0            7     8        6      7       6             6           6
# 1            7     6        5      4       6             6           6
# 2            7     6        6      5       6             6           6
# 3            7     6        6      5       6             6           9
# 4            7     6        5      5       6             9           6
# ...        ...   ...      ...    ...     ...           ...         ...
# 77873        7     5        5      5       6             9           9
# 77874        7    10        6      4       5             9           9
# 77875        7    10        2      2       6             9          13
# 77876        7     6        6      6       6             6           6
# 77877        7     5        6      7       6             9           6
#
#        Fuel Efficiency
# 0                    6
# 1                    6
# 2                    5
# ...

# %% [markdown]
# # Find the data which satisfy specific condition using df.query()

# %%
df.query("Product == 'Suzuki'")
# Out:
#        Address        city Product   model  engine transmission registered  \
# 3      7943733      Lahore  Suzuki   Swift  1300.0       Manual  Islamabad
# 6      7764683   Islamabad  Suzuki   Swift  1300.0       Manual  Islamabad
# 11     7943741      Lahore  Suzuki  Mehran   796.0       Manual     Lahore
# 18     7943726  Gujranwala  Suzuki  Cultus  1000.0       Manual     Lahore
# 21     7943730       Kasur  Suzuki    Alto   660.0       Manual     Punjab
# ...        ...         ...     ...     ...     ...          ...        ...
# 77867  7772648   Islamabad  Suzuki  Cultus  1000.0       Manual     Punjab
# 77868  7772762   Islamabad  Suzuki   Every   660.0    Automatic  Islamabad
# 77872  7773736   Islamabad  Suzuki   Wagon  1000.0       Manual  Islamabad
# 77874  7772775  Abbottabad  Suzuki    Alto   660.0    Automatic  Islamabad
# 77876  7322377      Quetta  Suzuki  Baleno  1300.0       Manual     Lahore
#
#        Fuel Efficiency
# 3                87000
# ...

# %% [markdown]
# # Perform grouping and aggregating operations using df.groupby() and df.agg().

# %%
groupdf = df.groupby('Address').first()
groupdf
# Out:
#                city Product   model  engine transmission registered  \
# Address
# 274897    Islamabad  Suzuki  Khyber  1000.0       Manual  Islamabad
# 447811      Karachi  Suzuki   Liana  1300.0       Manual    Karachi
# 751852       Lahore  Suzuki   Swift  1300.0    Automatic     Lahore
# 1117870      Lahore  Toyota    Aqua  1500.0    Automatic     Punjab
# 1149814   Islamabad   Honda   Civic  1800.0       Manual  Islamabad
# ...             ...     ...     ...     ...          ...        ...
# 7943736      Vehari   Honda   Civic  1300.0    Automatic     Punjab
# 7943737      Lahore  Toyota   Yaris  1300.0       Manual     Punjab
# 7943739  Faisalabad   Honda    City  1300.0    Automatic     Lahore
# 7943740     Sialkot  Toyota   Yaris  1300.0    Automatic     Punjab
# 7943741      Lahore  Suzuki  Mehran   796.0       Manual     Lahore
#
#          Fuel Efficiency
# Address
# 274897             78000
# 447811            140000
# 751852             95000
# 1117870            82000
# ...

# %%
print(groupdf["Fuel Efficiency"].agg('sum'))
print(groupdf["Fuel Efficiency"].agg('min'))
print(groupdf["Fuel Efficiency"].agg('max'))
# Out:
# 7095401713
# 1
# 1000000

# %% [markdown]
# # Practice imputing missing values using the SimpleImput er Class in sklearn

# %%
import sklearn as skl
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='most_frequent', fill_value=0)
imputer.fit(df[['Address']])
df['Address'] = imputer.transform(df[['Address']])
df
# Out:
#        Address        city Product    model  engine transmission  \
# 0      7943732    Peshawar  Toyota  Corolla  1300.0       Manual
# 1      7730314      Lahore   Honda     City  1300.0       Manual
# 2      7943737      Lahore  Toyota    Yaris  1300.0       Manual
# 3      7943733      Lahore  Suzuki    Swift  1300.0       Manual
# 4      7923484      Lahore   Honda    Civic  1800.0    Automatic
# ...        ...         ...     ...      ...     ...          ...
# 77873  7775164       Daska   Honda    Civic  1800.0    Automatic
# 77874  7772775  Abbottabad  Suzuki     Alto   660.0    Automatic
# 77875  7773716  Faisalabad      MG       HS  1490.0    Automatic
# 77876  7322377      Quetta  Suzuki   Baleno  1300.0       Manual
# 77877  7770898       Mandi  Toyota  Corolla  1600.0    Automatic
#
#           registered  Fuel Efficiency
# 0             Lahore           145000
# 1             Lahore           230000
# 2             Punjab            60500
# ...

# %%
df.isnull().sum()
# Out:
# Address            0
# city               0
# Product            0
# model              0
# engine             0
# transmission       0
# registered         0
# Fuel Efficiency    0
# dtype: int64

# %%
np.random.seed(50) #gets the randomized seed

random_mask = np.random.choice([True, False], size=len(df)) # Generate a random mask based on the random seed

df.loc[random_mask, 'Address'] = np.nan

# %% [markdown]
# # Extra Miles

# %% [markdown]
# # Cleaning my CSV File

# %%
# Define the regular expression to match 'Un-Registered'
regex_pattern = r'Un-Registered'

# Create a new 'eligible' column based on the 'registered' column
df['eligible'] = df['registered'].apply(lambda x: 'Eligible' if x != 'Un-Registered' else 'Ineligible')

# Print the updated DataFrame
df
# Out:
#          Address        city Product    model  engine transmission  \
# 0            NaN    Peshawar  Toyota  Corolla  1300.0       Manual
# 1            NaN      Lahore   Honda     City  1300.0       Manual
# 2      7943737.0      Lahore  Toyota    Yaris  1300.0       Manual
# 3      7943733.0      Lahore  Suzuki    Swift  1300.0       Manual
# 4      7923484.0      Lahore   Honda    Civic  1800.0    Automatic
# ...          ...         ...     ...      ...     ...          ...
# 77873        NaN       Daska   Honda    Civic  1800.0    Automatic
# 77874        NaN  Abbottabad  Suzuki     Alto   660.0    Automatic
# 77875  7773716.0  Faisalabad      MG       HS  1490.0    Automatic
# 77876  7322377.0      Quetta  Suzuki   Baleno  1300.0       Manual
# 77877  7770898.0       Mandi  Toyota  Corolla  1600.0    Automatic
#
#           registered  Fuel Efficiency    eligible
# 0             Lahore           145000    Eligible
# 1             Lahore           230000    Eligible
# ...

# %% [markdown]
# # Clean the text and nested json in

# %%
ExMidf = pd.read_csv('movies_metadata.csv')
ExMidf
# Out:
# C:\Users\Ivandito\AppData\Local\Temp\ipykernel_84808\1700993446.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   ExMidf = pd.read_csv('movies_metadata.csv')
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# ...

# %%
import ast
ExMidf.dropna(subset = ["belongs_to_collection"], inplace = True)
ExMidf
collectionList = ExMidf['belongs_to_collection'].tolist()
idL = []
nameL = []
posterPthL = []
bckDrpPthL = []
collectionList
def verify(tempdict, col, array):
    try:
        array.append(tempdict[col])
    except:
        array.append("None")
for col in collectionList:
    try:
        tempdict = ast.literal_eval(col) ##Change string to dict
        verify(tempdict, "id", idL)
        verify(tempdict, "name", nameL)
        verify(tempdict, "poster_path", posterPthL)
        verify(tempdict, "backdrop_path", bckDrpPthL)
    except:
        idL.append("None")
        nameL.append("None")
        posterPthL.append("None")
        bckDrpPthL.append("None")
ExMidfDict = {
    "ID": idL,
    "name": nameL,
    "poster path":posterPthL,
    "backdrop path":bckDrpPthL
}
newDf = pd.DataFrame.from_dict(ExMidfDict)
newDf
# Out:
#           ID                            name  \
# 0      10194            Toy Story Collection
# 1     119050       Grumpy Old Men Collection
# 2      96871  Father of the Bride Collection
# 3        645           James Bond Collection
# 4     117693                Balto Collection
# ...      ...                             ...
# 4489   37261         The Carry On Collection
# 4490   37261         The Carry On Collection
# 4491   37261         The Carry On Collection
# 4492  477208  DC Super Hero Girls Collection
# 4493  200641            Red Lotus Collection
#
#                            poster path                     backdrop path
# 0     /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1     /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 2     /nts4iOmNnq7GNicycMJ9pSAn204.jpg  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
# 3      /HORpg5CSkmeQlAolx3bKMrKgfi.jpg  /6VcVl48kNKvdXOZfJPdarlUGOsk.jpg
# ...

# %%
genreList = ExMidf["genres"].tolist()
genreIDL = []
genreNameL= []
extracted_data = []
for i in genreList:
    data_list = ast.literal_eval(i)
    extracted_data.append(data_list)
doubleArrayGenreID = []
doubleArrayNameGenre = []
for i in extracted_data:
    tempGroupID = []
    tempGroupName = []
    for j in i:
        tempGroupID.append(j["id"])
        tempGroupName.append(j["name"])
    doubleArrayGenreID.append(tempGroupID)
    doubleArrayNameGenre.append(tempGroupName)
ExMidfDict = {
    "ID": idL,
    "name": nameL,
    "poster path":posterPthL,
    "backdrop path":bckDrpPthL,
    "genre ID": doubleArrayGenreID,
    "genre name": doubleArrayNameGenre
}
newDf = pd.DataFrame.from_dict(ExMidfDict)
newDf
# Out:
#           ID                            name  \
# 0      10194            Toy Story Collection
# 1     119050       Grumpy Old Men Collection
# 2      96871  Father of the Bride Collection
# 3        645           James Bond Collection
# 4     117693                Balto Collection
# ...      ...                             ...
# 4489   37261         The Carry On Collection
# 4490   37261         The Carry On Collection
# 4491   37261         The Carry On Collection
# 4492  477208  DC Super Hero Girls Collection
# 4493  200641            Red Lotus Collection
#
#                            poster path                     backdrop path  \
# 0     /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1     /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 2     /nts4iOmNnq7GNicycMJ9pSAn204.jpg  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
# 3      /HORpg5CSkmeQlAolx3bKMrKgfi.jpg  /6VcVl48kNKvdXOZfJPdarlUGOsk.jpg
# ...

# %%
productionCompanyList = ExMidf["production_companies"].tolist()
nameCompanyL = []
idCompanyL= []
extracted_data = []
for i in productionCompanyList:
    try:
        data_list = ast.literal_eval(i)
    except:
        data_list = {'name':'None', 'id':'None'}
    extracted_data.append(data_list)
extracted_data
doubleArrayNameCompany = []
doubleArrayIdCompany = []
counter = 0
for i in extracted_data:
    tempGroupIdCompany = []
    tempGroupNameCompany = []
    try:
        for j in i:
            tempGroupIdCompany.append(j["id"])
            tempGroupNameCompany.append(j["name"])
    except:
        tempGroupIdCompany.append("None")
        tempGroupNameCompany.append("None")
    doubleArrayNameCompany.append(tempGroupNameCompany)
    doubleArrayIdCompany.append(tempGroupIdCompany)
ExMidfDict = {
    "ID": idL,
    "name": nameL,
    "poster path":posterPthL,
    "backdrop path":bckDrpPthL,
    "genre ID": doubleArrayGenreID,
    "genre name": doubleArrayNameGenre,
    "Production Company Name": doubleArrayNameCompany,
    "ID Company":doubleArrayIdCompany
}
newDf = pd.DataFrame.from_dict(ExMidfDict)
newDf
# Out:
#           ID                            name  \
# 0      10194            Toy Story Collection
# 1     119050       Grumpy Old Men Collection
# 2      96871  Father of the Bride Collection
# 3        645           James Bond Collection
# 4     117693                Balto Collection
# ...      ...                             ...
# 4489   37261         The Carry On Collection
# 4490   37261         The Carry On Collection
# 4491   37261         The Carry On Collection
# 4492  477208  DC Super Hero Girls Collection
# 4493  200641            Red Lotus Collection
#
#                            poster path                     backdrop path  \
# 0     /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1     /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 2     /nts4iOmNnq7GNicycMJ9pSAn204.jpg  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
# 3      /HORpg5CSkmeQlAolx3bKMrKgfi.jpg  /6VcVl48kNKvdXOZfJPdarlUGOsk.jpg
# ...

# %%
productionCountriesList = ExMidf["production_countries"].tolist()
isoCompanyL = []
nameCountryL= []
extracted_data = []
for i in productionCountriesList:
    try:
        data_list = ast.literal_eval(i)
    except:
        data_list = {'iso_3166_1':'None', 'name':'None'}
    extracted_data.append(data_list)
doubleArrayIso = []
doubleArrayNameCountry = []
for i in extracted_data:
    tempGroupIsoCompany = []
    tempGroupnameCountry = []
    try:
        for j in i:
            tempGroupIsoCompany.append(j['iso_3166_1'])
            tempGroupnameCountry.append(j['name'])
    except:
        tempGroupIsoCompany.append("None")
        tempGroupnameCountry.append("None")
    doubleArrayNameCountry.append(tempGroupnameCountry)
    doubleArrayIso.append(tempGroupIsoCompany) 
emdfDict = {
    "ID": idL,
    "name": nameL,
    "poster path":posterPthL,
    "backdrop path":bckDrpPthL,
    "genre ID": doubleArrayGenreID,
    "genre name": doubleArrayNameGenre,
    "Production Company Name": doubleArrayNameCompany,
    "Language": doubleArrayIso,
    "Country": doubleArrayNameCountry
}
newDf = pd.DataFrame.from_dict(ExMidfDict)
newDf
# Out:
#           ID                            name  \
# 0      10194            Toy Story Collection
# 1     119050       Grumpy Old Men Collection
# 2      96871  Father of the Bride Collection
# 3        645           James Bond Collection
# 4     117693                Balto Collection
# ...      ...                             ...
# 4489   37261         The Carry On Collection
# 4490   37261         The Carry On Collection
# 4491   37261         The Carry On Collection
# 4492  477208  DC Super Hero Girls Collection
# 4493  200641            Red Lotus Collection
#
#                            poster path                     backdrop path  \
# 0     /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1     /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 2     /nts4iOmNnq7GNicycMJ9pSAn204.jpg  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
# 3      /HORpg5CSkmeQlAolx3bKMrKgfi.jpg  /6VcVl48kNKvdXOZfJPdarlUGOsk.jpg
# ...

# %%
spokenLanguagesList = ExMidf["spoken_languages"].tolist()
dubbingisoL = []
dubbingnameL= []
extracted_data = []
for i in spokenLanguagesList:
    try:
        data_list = ast.literal_eval(i)
    except:
        data_list = {'iso_639_1':'None', 'name':'None'}
    extracted_data.append(data_list)
doubleArrayDubbingIso = []
doubleArrayDubbingNameL = []
for i in extracted_data:
    tempGroupDubbingIso = []
    tempGroupDubbingName = []
    try:
        for j in i:
            tempGroupDubbingIso.append(j['iso_639_1'])
            tempGroupDubbingName.append(j['name'])
    except:
        tempGroupIsoCompany.append("None")
        tempGroupnameCountry.append("None")
    doubleArrayDubbingIso.append(tempGroupDubbingIso)
    doubleArrayDubbingNameL.append(tempGroupDubbingName) 
ExMidfDict = {
    "ID": idL,
    "name": nameL,
    "poster path":posterPthL,
    "backdrop path":bckDrpPthL,
    "genre ID": doubleArrayGenreID,
    "genre name": doubleArrayNameGenre,
    "Production Company Name": doubleArrayNameCompany,
    "Language": doubleArrayIso,
    "Country": doubleArrayNameCountry,
    "Dubbing Lang": doubleArrayDubbingIso,
    "Dubbing Name": doubleArrayDubbingNameL
} 
newDf = pd.DataFrame.from_dict(ExMidfDict)
newDf
# Out:
#           ID                            name  \
# 0      10194            Toy Story Collection
# 1     119050       Grumpy Old Men Collection
# 2      96871  Father of the Bride Collection
# 3        645           James Bond Collection
# 4     117693                Balto Collection
# ...      ...                             ...
# 4489   37261         The Carry On Collection
# 4490   37261         The Carry On Collection
# 4491   37261         The Carry On Collection
# 4492  477208  DC Super Hero Girls Collection
# 4493  200641            Red Lotus Collection
#
#                            poster path                     backdrop path  \
# 0     /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1     /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 2     /nts4iOmNnq7GNicycMJ9pSAn204.jpg  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
# 3      /HORpg5CSkmeQlAolx3bKMrKgfi.jpg  /6VcVl48kNKvdXOZfJPdarlUGOsk.jpg
# ...

# %%
ExMidf.drop('belongs_to_collection', axis = 1, inplace= True)
ExMidf.drop('genres', axis = 1, inplace= True)
ExMidf.drop('production_companies', axis = 1, inplace= True)
ExMidf.drop('production_countries', axis = 1, inplace= True)
ExMidf.drop('spoken_languages', axis = 1, inplace= True)

# %%
ExMidf
# Out:
#        adult    budget                                      homepage      id  \
# 0      False  30000000          http://toystory.disney.com/toy-story     862
# 2      False         0                                           NaN   15602
# 4      False         0                                           NaN   11862
# 9      False  58000000  http://www.mgm.com/view/movie/757/Goldeneye/     710
# 12     False         0                                           NaN   21032
# ...      ...       ...                                           ...     ...
# 45355  False         0                                           NaN   24568
# 45358  False         0                                           NaN   19307
# 45369  False         0                                           NaN   21251
# 45371  False         0                                           NaN  460135
# 45382  False         0                                           NaN  182030
#
# ...

# %%
ExMidf["ID"] = idL
ExMidf["name"]= nameL
ExMidf["poster path"] = posterPthL
ExMidf["backdrop path"]= bckDrpPthL
ExMidf["genre ID"] = doubleArrayGenreID
ExMidf["genre name"] =  doubleArrayNameGenre
ExMidf["Production Company Name"] = doubleArrayNameCompany
ExMidf["Language"] =  doubleArrayIso
ExMidf["Country"] = doubleArrayNameCountry
ExMidf["Dubbing Lang"] = doubleArrayDubbingIso
ExMidf["Dubbing Name"] = doubleArrayDubbingNameL

# %%
ExMidf
# Out:
#        adult    budget                                      homepage      id  \
# 0      False  30000000          http://toystory.disney.com/toy-story     862
# 2      False         0                                           NaN   15602
# 4      False         0                                           NaN   11862
# 9      False  58000000  http://www.mgm.com/view/movie/757/Goldeneye/     710
# 12     False         0                                           NaN   21032
# ...      ...       ...                                           ...     ...
# 45355  False         0                                           NaN   24568
# 45358  False         0                                           NaN   19307
# 45369  False         0                                           NaN   21251
# 45371  False         0                                           NaN  460135
# 45382  False         0                                           NaN  182030
#
# ...
